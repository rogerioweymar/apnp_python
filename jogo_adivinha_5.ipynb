# %% [markdown]
# Aula 1

# %%
print('*************')
print('JoGo AdiVinHa')
print('*************')


print('░░░░░▄▄▀▀▀▀▀▀▀▀▀▄▄░░░░░')
print('░░░░█░░░░░░░░░░░░░█░░░░')
print('░░░█░░░░░░░░░░▄▄▄░░█░░░')
print('░░░█░░▄▄▄░░▄░░███░░█░░░')
print('░░░▄█░▄░░░▀▀▀░░░▄░█▄░░░')
print('░░░█░░▀█▀█▀█▀█▀█▀░░█░░░')
print('░░░▄██▄▄▀▀▀▀▀▀▀▄▄██▄░░░')
print('░▄█░█▀▀█▀▀▀█▀▀▀█▀▀█░█▄░')
print('▄▀░▄▄▀▄▄▀▀▀▄▀▀▀▄▄▀▄▄░▀▄')
print('█░░░░▀▄░█▄░░░▄█░▄▀░░░░█')
print('░▀▄▄░█░░█▄▄▄▄▄█░░█░▄▄▀░')
print('░░░▀██▄▄███████▄▄██▀░░░')
print('░░░████████▀████████░░░')
print('░░▄▄█▀▀▀▀█░░░█▀▀▀▀█▄▄░░')
print('░░▀▄▄▄▄▄▀▀░░░▀▀▄▄▄▄▄▀░')

numero_computador = 35

total_tentativas = 3

print('''     ____.                         _____       .___.__      .__       .__            
    |    | ____   ____   ____     /  _  \    __| _/|__|__  _|__| ____ |  |__ _____   
    |    |/  _ \ / ___\ /  _ \   /  /_\  \  / __ | |  \  \/ /  |/    \|  |  \\__  \  
/\__|    (  <_> ) /_/  >  <_> ) /    |    \/ /_/ | |  |\   /|  |   |  \   Y  \/ __ \_
\________|\____/\___  / \____/  \____|__  /\____ | |__| \_/ |__|___|  /___|  (____  /
               /_____/                  \/      \/                  \/     \/     \/ ''')

for sequencia in range(1, total_tentativas + 1):
  print ("Total de tentativas", sequencia)
  minha_escolha = int(input("Digite um número: "))
  print("Você digitou", minha_escolha,"e o número que pensei foi", numero_computador)

  if numero_computador == minha_escolha:
    print("Você acertou")
  else:
    if minha_escolha > numero_computador:
     print("Você errou e seu chute foi maior que o numero que pensei")
    if minha_escolha < numero_computador:
      print("Você errou e seu chute foi menor que o numero que pensei")
# Out:
# *************
# JoGo AdiVinHa
# *************
# ░░░░░▄▄▀▀▀▀▀▀▀▀▀▄▄░░░░░
# ░░░░█░░░░░░░░░░░░░█░░░░
# ░░░█░░░░░░░░░░▄▄▄░░█░░░
# ░░░█░░▄▄▄░░▄░░███░░█░░░
# ░░░▄█░▄░░░▀▀▀░░░▄░█▄░░░
# ░░░█░░▀█▀█▀█▀█▀█▀░░█░░░
# ░░░▄██▄▄▀▀▀▀▀▀▀▄▄██▄░░░
# ░▄█░█▀▀█▀▀▀█▀▀▀█▀▀█░█▄░
# ▄▀░▄▄▀▄▄▀▀▀▄▀▀▀▄▄▀▄▄░▀▄
# █░░░░▀▄░█▄░░░▄█░▄▀░░░░█
# ░▀▄▄░█░░█▄▄▄▄▄█░░█░▄▄▀░
# ░░░▀██▄▄███████▄▄██▀░░░
# ░░░████████▀████████░░░
# ░░▄▄█▀▀▀▀█░░░█▀▀▀▀█▄▄░░
# ░░▀▄▄▄▄▄▀▀░░░▀▀▄▄▄▄▄▀░
#      ____.                         _____       .___.__      .__       .__
#     |    | ____   ____   ____     /  _  \    __| _/|__|__  _|__| ____ |  |__ _____
#     |    |/  _ \ / ___\ /  _ \   /  /_\  \  / __ | |  \  \/ /  |/    \|  |  \__  \
# /\__|    (  <_> ) /_/  >  <_> ) /    |    \/ /_/ | |  |\   /|  |   |  \   Y  \/ __ \_
# \________|\____/\___  / \____/  \____|__  /\____ | |__| \_/ |__|___|  /___|  (____  /
#                /_____/                  \/      \/                  \/     \/     \/
# Total de tentativas 1
# Digite um número: 6
# Você digitou 6 e o número que pensei foi 35
# Você errou e seu chute foi menor que o numero que pensei
# Total de tentativas 2
# Digite um número: 30
# Você digitou 30 e o número que pensei foi 35
# Você errou e seu chute foi menor que o numero que pensei
# Total de tentativas 3
# Digite um número: 50
# Você digitou 50 e o número que pensei foi 35
# Você errou e seu chute foi maior que o numero que pensei
